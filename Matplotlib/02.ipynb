# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

# %%
plt.bar(years,runs)
plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("Sachine Runs")
# Out:
# Text(0.5, 1.0, 'Sachine Runs')

# %%
import numpy as np

sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0]
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

x = np.arange(len(years))  # index positions

# %%
width = 0.25
plt.bar(x-width,sachin,width=width,label="Sachin")
plt.bar(x,sachin,width=width,label="Sehwag")
plt.bar(x+width,sachin,width=width,label="Kholi")
plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("Runs Compare")
plt.xticks(x,years) #Shows the actual years instead of 0,1,2,3,4,....count
plt.tight_layout()
plt.legend()

# %%
players=["Sachin","Kholi","Sehwag","UV"]
runs_5yrs = [500+700+1100+1500+1800, 0+200+900+1400+1600, 0+0+500+800+1100, 300+600+800+1100+900]
plt.barh(players, runs_5yrs, color="skyblue")
plt.xlabel("Total Runs in First 5 Years")
plt.title("First 5-Year Performance of Indian Batsmen")
plt.tight_layout()
plt.show()

# %%
player=['A','B','C']
runs=[100,40,90]

plt.bar(player,runs,color="purple")
for i in range(len(player)):
    plt.text(i,runs[i]+1,str(runs[i]),ha="center")

plt.ylabel("Runs")
plt.title("Runs Scored by Players")
plt.tight_layout()
plt.show()
